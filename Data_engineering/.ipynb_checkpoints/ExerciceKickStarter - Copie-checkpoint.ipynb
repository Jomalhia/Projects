# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %%
df_ks['goal']=df_ks['goal'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_ks['pledged']=df_ks['pledged'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_ks['backers']=df_ks['backers'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_ks['usd pledged']=df_ks['usd pledged'].apply(lambda x: pd.to_numeric(x, errors='coerce',downcast='float'))

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks.shape
# Out:
# (150000, 14)

# %%
df_ks.dropna(axis=0,inplace=True)

# %%
df_ks.shape
# Out:
# (148515, 14)

# %%
df_ks.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'goal', 'launched', 'pledged', 'state', 'backers', 'country',
#        'usd pledged', 'usd_pledged_real'],
#       dtype='object')

# %%
df_sample=df_ks.sample(frac=1/4,axis=0)
df_sample.shape
# Out:
# (37129, 14)

# %%
df_ks.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                float64
# launched             object
# pledged             float64
# state                object
# backers             float64
# country              object
# usd pledged         float64
# usd_pledged_real    float64
# dtype: object

# %% [markdown]
# ### Importer les données

# %%
def slice_generator(df, chunk_size=10):
    current_row = 0
    total_rows = df.shape[0]
    while current_row < total_rows:
        yield df[current_row:current_row + chunk_size]
        current_row += chunk_size

# %%
for df_chunk in slice_generator(df_sample):
    records = df_chunk.to_dict(orient='records')
    collection.insert_many(records)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5fc0f4a1e9c6ebd4718869ad'),
#  'ID': '872782264',
#  'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#  'category': 'Rock',
#  'main_category': 'Music',
#  'currency': 'USD',
#  'deadline': '2011-09-16',
#  'goal': '2000.0',
#  'launched': '2011-08-17 06:31:31',
#  'pledged': '1145.0',
#  'state': 'canceled',
#  'backers': '24',
#  'country': 'US',
#  'usd pledged': '1145.0',
#  'usd_pledged_real': '1145.0'}

# %% [markdown]
# ## Question 1

# %% [markdown]
# cur=collection.find().sort('backers',-1).limit(5)
# list(cur)

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$ID", "averagebackers" : {"$avg" : "$backers"}}},{"$sort":{"averagebackers":-1}},{"$limit":5}])
list(cur)
# Out:
# [{'_id': 1386523707, 'averagebackers': 154926.0},
#  {'_id': 1755266685, 'averagebackers': 91585.0},
#  {'_id': 286165030, 'averagebackers': 74405.0},
#  {'_id': 2095857140, 'averagebackers': 70122.0},
#  {'_id': 2103598555, 'averagebackers': 66673.0}]

# %% [markdown]
# ## Question 2

# %%
collection.find({"state":"successful"}).count(True)
# Out:
# <ipython-input-23-3717aac12a2b>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({"state":"successful"}).count(True)
# 371579

# %% [markdown]
# ## Question 3

# %%
cur=collection.aggregate([{"$group":{"_id":"$category","total":{"$sum":1}}}])
list(cur)
# Out:
# [{'_id': 'Apps', 'total': 17754},
#  {'_id': 'Video', 'total': 1035},
#  {'_id': 'Plays', 'total': 3776},
#  {'_id': "Children's Books", 'total': 18900},
#  {'_id': 'Conceptual Art', 'total': 2743},
#  {'_id': 'Live Games', 'total': 2765},
#  {'_id': 'Tabletop Games', 'total': 38993},
#  {'_id': 'World Music', 'total': 5959},
#  {'_id': 'Illustration', 'total': 8786},
#  {'_id': 'Space Exploration', 'total': 969},
#  {'_id': 'Typography', 'total': 308},
#  {'_id': 'Couture', 'total': 761},
#  {'_id': 'Places', 'total': 1959},
#  {'_id': 'Pet Fashion', 'total': 359},
#  {'_id': 'Crochet', 'total': 426},
#  {'_id': 'Farms', 'total': 3384},
#  {'_id': 'Footwear', 'total': 2641},
#  {'_id': 'Science Fiction', 'total': 1943},
#  {'_id': 'Mixed Media', 'total': 7822},
#  {'_id': 'Stationery', 'total': 626},
#  {'_id': 'DIY Electronics', 'total': 2496},
#  {'_id': 'Painting', 'total': 9037},
#  {'_id': 'Metal', 'total': 1929},
#  {'_id': 'Webseries', 'total': 16198},
#  {'_id': 'Camera Equipment', 'total': 1142},
#  {'_id': 'Architecture', 'total': 2113},
#  {'_id': 'Electronic Music', 'total': 5994},
#  {'_id': 'Film & Video', 'total': 26638},
#  {'_id': 'Fine Art', 'total': 2057},
#  {'_id': 'Software', 'total': 8353},
#  {'_id': 'Childrenswear', 'total': 1352},
#  {'_id': 'Spaces', 'total': 2331},
#  {'_id': 'Journalism', 'total': 4708},
#  {'_id': 'DIY', 'total': 3353},
#  {'_id': 'Jazz', 'total': 5137},
#  {'_id': 'Photo', 'total': 401},
#  {'_id': 'Latin', 'total': 451},
#  {'_id': 'Sculpture', 'total': 5175},
#  {'_id': 'Taxidermy', 'total': 51},
#  {'_id': 'Glass', 'total': 353},
#  {'_id': 'Shorts', 'total': 33990},
#  {'_id': 'Music Videos', 'total': 2098},
#  {'_id': 'Anthologies', 'total': 2099},
#  {'_id': 'Hardware', 'total': 10032},
#  {'_id': 'Playing Cards', 'total': 6742},
#  {'_id': 'Residencies', 'total': 224},
#  {'_id': 'Horror', 'total': 3685},
#  {'_id': 'Fashion', 'total': 23660},
#  {'_id': 'Sound', 'total': 1775},
#  {'_id': 'Installations', 'total': 1256},
#  {'_id': 'Hip-Hop', 'total': 10908},
#  {'_id': 'Crafts', 'total': 12882},
#  {'_id': 'Restaurants', 'total': 7592},
#  {'_id': 'Cookbooks', 'total': 1506},
#  {'_id': 'Fabrication Tools', 'total': 663},
#  {'_id': 'Pottery', 'total': 280},
#  {'_id': 'Knitting', 'total': 536},
#  {'_id': 'Digital Art', 'total': 3689},
#  {'_id': 'Nonfiction', 'total': 23750},
#  {'_id': 'Photography', 'total': 15755},
#  {'_id': 'Young Adult', 'total': 2310},
#  {'_id': 'Gadgets', 'total': 8441},
#  {'_id': 'Academic', 'total': 2566},
#  {'_id': 'Ready-to-wear', 'total': 2315},
#  {'_id': 'Video Art', 'total': 464},
#  {'_id': 'Art', 'total': 23512},
#  {'_id': 'People', 'total': 3046},
#  {'_id': 'Flight', 'total': 1103},
#  {'_id': 'Apparel', 'total': 19774},
#  {'_id': 'Music', 'total': 39974},
#  {'_id': 'Classical Music', 'total': 7456},
#  {'_id': 'Woodworking', 'total': 3015},
#  {'_id': 'Art Books', 'total': 7453},
#  {'_id': 'Theater', 'total': 19556},
#  {'_id': 'Product Design', 'total': 62172},
#  {'_id': 'Civic Design', 'total': 896},
#  {'_id': 'Experimental', 'total': 2507},
#  {'_id': 'Webcomics', 'total': 1832},
#  {'_id': 'Accessories', 'total': 8406},
#  {'_id': 'Family', 'total': 909},
#  {'_id': 'Indie Rock', 'total': 15325},
#  {'_id': 'Chiptune', 'total': 76},
#  {'_id': 'Interactive Design', 'total': 1027},
#  {'_id': 'Small Batch', 'total': 4924},
#  {'_id': 'Calendars', 'total': 804},
#  {'_id': 'Textiles', 'total': 750},
#  {'_id': 'Technology', 'total': 18751},
#  {'_id': 'Action', 'total': 1982},
#  {'_id': 'Festivals', 'total': 2192},
#  {'_id': 'Radio & Podcasts', 'total': 2423},
#  {'_id': 'Kids', 'total': 766},
#  {'_id': 'Letterpress', 'total': 163},
#  {'_id': 'Wearables', 'total': 3554},
#  {'_id': 'Embroidery', 'total': 340},
#  {'_id': 'Periodicals', 'total': 3606},
#  {'_id': 'Performance Art', 'total': 5990},
#  {'_id': 'Video Games', 'total': 33554},
#  {'_id': 'Animals', 'total': 692},
#  {'_id': 'Comics', 'total': 13502},
#  {'_id': "Farmer's Markets", 'total': 1229},
#  {'_id': 'Fiction', 'total': 26070},
#  {'_id': 'Rock', 'total': 19006},
#  {'_id': 'Comedy', 'total': 6440},
#  {'_id': 'Community Gardens', 'total': 820},
#  {'_id': 'Vegan', 'total': 1581},
#  {'_id': 'Public Art', 'total': 8699},
#  {'_id': 'Dance', 'total': 6296},
#  {'_id': 'Immersive', 'total': 917},
#  {'_id': 'Gaming Hardware', 'total': 1261},
#  {'_id': 'Print', 'total': 1987},
#  {'_id': 'Puzzles', 'total': 679},
#  {'_id': 'Animation', 'total': 7158},
#  {'_id': 'Television', 'total': 2810},
#  {'_id': 'Comic Books', 'total': 7245},
#  {'_id': 'Ceramics', 'total': 903},
#  {'_id': 'Makerspaces', 'total': 617},
#  {'_id': 'Documentary', 'total': 45390},
#  {'_id': 'Games', 'total': 9357},
#  {'_id': 'Graphic Design', 'total': 5349},
#  {'_id': 'Publishing', 'total': 15558},
#  {'_id': 'Robots', 'total': 1636},
#  {'_id': 'Punk', 'total': 892},
#  {'_id': 'Photobooks', 'total': 4248},
#  {'_id': 'Zines', 'total': 1013},
#  {'_id': 'Quilts', 'total': 229},
#  {'_id': 'Movie Theaters', 'total': 624},
#  {'_id': 'Narrative Film', 'total': 14706},
#  {'_id': 'Country & Folk', 'total': 12566},
#  {'_id': 'Jewelry', 'total': 3293},
#  {'_id': 'Design', 'total': 11462},
#  {'_id': 'Printing', 'total': 573},
#  {'_id': '3D Printing', 'total': 1910},
#  {'_id': 'Food Trucks', 'total': 4827},
#  {'_id': 'Translations', 'total': 531},
#  {'_id': 'R&B', 'total': 1206},
#  {'_id': 'Blues', 'total': 813},
#  {'_id': 'Workshops', 'total': 408},
#  {'_id': 'Bacon', 'total': 548},
#  {'_id': 'Literary Spaces', 'total': 67},
#  {'_id': 'Web', 'total': 14103},
#  {'_id': 'Food', 'total': 32414},
#  {'_id': 'Candles', 'total': 1176},
#  {'_id': 'Romance', 'total': 518},
#  {'_id': 'Thrillers', 'total': 2120},
#  {'_id': 'Musical', 'total': 2570},
#  {'_id': 'Performances', 'total': 2917},
#  {'_id': 'Drama', 'total': 6053},
#  {'_id': 'Graphic Novels', 'total': 4932},
#  {'_id': 'Poetry', 'total': 3715},
#  {'_id': 'Weaving', 'total': 273},
#  {'_id': 'Nature', 'total': 1507},
#  {'_id': 'Audio', 'total': 1150},
#  {'_id': 'Drinks', 'total': 6916},
#  {'_id': 'Faith', 'total': 3079},
#  {'_id': 'Fantasy', 'total': 928},
#  {'_id': 'Events', 'total': 2260},
#  {'_id': 'Mobile Games', 'total': 4539},
#  {'_id': 'Pop', 'total': 9129},
#  {'_id': 'Literary Journals', 'total': 822}]

# %% [markdown]
# ## Question 4

# %%
collection.find({"launched":{ "$lte" :  "2015-12-31"}}).count(True)
# Out:
# <ipython-input-25-6874adba7840>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({"launched":{ "$lte" :  "2015-12-31"}}).count(True)
# 740878

# %% [markdown]
# ## Question 5

# %%
cur=collection.find({"pledged":{ "$gte" :  200000}})
list(cur)
# Out:
# [{'_id': ObjectId('5fc28b87a366e0e4b8db182e'),
#   'ID': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 75000.0,
#   'launched': '2014-10-15 06:34:48',
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'backers': 10293.0,
#   'country': 'US',
#   'usd pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db18bd'),
#   'ID': 909248984,
#   'name': 'Redux COURG - Hybrid Watches with Missions to Tackle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-20',
#   'goal': 30000.0,
#   'launched': '2015-07-21 19:01:41',
#   'pledged': 692912.0,
#   'state': 'successful',
#   'backers': 2200.0,
#   'country': 'US',
#   'usd pledged': 692912.0,
#   'usd_pledged_real': 692912.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1918'),
#   'ID': 2077379837,
#   'name': 'Battle Systemsï¿½ Sci-fi II Terrain',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2016-11-20',
#   'goal': 21000.0,
#   'launched': '2016-10-21 21:00:24',
#   'pledged': 241517.0,
#   'state': 'successful',
#   'backers': 1513.0,
#   'country': 'GB',
#   'usd pledged': 24261.91200558,
#   'usd_pledged_real': 300315.83790303534},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db196a'),
#   'ID': 1688905333,
#   'name': 'Legion Solar - A Better Way to Energy Independence',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 50000.0,
#   'launched': '2016-05-03 16:00:22',
#   'pledged': 277524.0,
#   'state': 'successful',
#   'backers': 399.0,
#   'country': 'US',
#   'usd pledged': 277524.0,
#   'usd_pledged_real': 277524.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1a5d'),
#   'ID': 1426744634,
#   'name': 'Earin - The Worlds Smallest Wireless Earbuds',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-07-23',
#   'goal': 179000.0,
#   'launched': '2014-06-13 23:08:09',
#   'pledged': 972594.99,
#   'state': 'successful',
#   'backers': 8359.0,
#   'country': 'GB',
#   'usd pledged': 1633748.50090932,
#   'usd_pledged_real': 1652246.6491123757},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1a87'),
#   'ID': 447408232,
#   'name': 'Edyn: Welcome to the connected garden.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-08',
#   'goal': 100000.0,
#   'launched': '2014-06-05 13:50:13',
#   'pledged': 384201.63,
#   'state': 'successful',
#   'backers': 2336.0,
#   'country': 'US',
#   'usd pledged': 384201.63,
#   'usd_pledged_real': 384201.63},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1a96'),
#   'ID': 1919184836,
#   'name': 'Period Panties',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-03-09',
#   'goal': 10000.0,
#   'launched': '2014-02-07 15:32:50',
#   'pledged': 404763.3,
#   'state': 'successful',
#   'backers': 9550.0,
#   'country': 'US',
#   'usd pledged': 404763.3,
#   'usd_pledged_real': 404763.3},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1b4a'),
#   'ID': 1148163608,
#   'name': 'Smartkase for iPhone 7 - Dual Sim +Memory Card +Battery Case',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-11',
#   'goal': 50000.0,
#   'launched': '2016-09-21 16:39:06',
#   'pledged': 281995.6,
#   'state': 'successful',
#   'backers': 3296.0,
#   'country': 'US',
#   'usd pledged': 3753.0,
#   'usd_pledged_real': 281995.6},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1b65'),
#   'ID': 253231219,
#   'name': 'Project: "Time" Short Film',
#   'category': 'Music Videos',
#   'main_category': 'Film & Video',
#   'currency': 'MXN',
#   'deadline': '2017-09-15',
#   'goal': 275000.0,
#   'launched': '2017-08-11 19:08:51',
#   'pledged': 295972.0,
#   'state': 'successful',
#   'backers': 73.0,
#   'country': 'MX',
#   'usd pledged': 5086.611508,
#   'usd_pledged_real': 16751.867783563506},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1b7d'),
#   'ID': 828587276,
#   'name': 'Shadowrun: Hong Kong',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-17',
#   'goal': 100000.0,
#   'launched': '2015-01-13 18:45:24',
#   'pledged': 1204726.47,
#   'state': 'successful',
#   'backers': 31497.0,
#   'country': 'US',
#   'usd pledged': 1204726.47,
#   'usd_pledged_real': 1204726.47},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1bf3'),
#   'ID': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': '2015-02-10 14:05:34',
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755.0,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1c48'),
#   'ID': 1075169964,
#   'name': 'Battle Worlds: Kronos - Turn-based strategy revisited',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-04-28',
#   'goal': 120000.0,
#   'launched': '2013-03-19 10:44:15',
#   'pledged': 260235.9,
#   'state': 'successful',
#   'backers': 7564.0,
#   'country': 'US',
#   'usd pledged': 260235.9,
#   'usd_pledged_real': 260235.9},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1cdb'),
#   'ID': 1339618489,
#   'name': 'Hie Diaper Bag: Your New Best Friend',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-07-15',
#   'goal': 60000.0,
#   'launched': '2017-06-12 17:54:56',
#   'pledged': 395666.0,
#   'state': 'successful',
#   'backers': 1882.0,
#   'country': 'US',
#   'usd pledged': 259582.0,
#   'usd_pledged_real': 395666.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1d34'),
#   'ID': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': '2014-12-10 18:58:08',
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096.0,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1db6'),
#   'ID': 956638568,
#   'name': 'Dobot: Robotic Arm for Everyone, Arduino & Open Source',
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-11-04',
#   'goal': 36000.0,
#   'launched': '2015-09-15 14:53:19',
#   'pledged': 615600.0,
#   'state': 'successful',
#   'backers': 1208.0,
#   'country': 'US',
#   'usd pledged': 615600.0,
#   'usd_pledged_real': 615600.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db1e40'),
#   'ID': 1224377216,
#   'name': 'ECLIPSE - Say Goodbye to Messy Cables',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-18',
#   'goal': 50000.0,
#   'launched': '2016-10-26 16:52:24',
#   'pledged': 939071.99,
#   'state': 'successful',
#   'backers': 8907.0,
#   'country': 'US',
#   'usd pledged': 156282.0,
#   'usd_pledged_real': 939071.99},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db2078'),
#   'ID': 1299968108,
#   'name': 'PolySmooth & Polysher: 3D Prints Without Layers',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-05-25',
#   'goal': 100000.0,
#   'launched': '2016-04-25 17:59:57',
#   'pledged': 433860.0,
#   'state': 'successful',
#   'backers': 1343.0,
#   'country': 'US',
#   'usd pledged': 433860.0,
#   'usd_pledged_real': 433860.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db20b0'),
#   'ID': 872005095,
#   'name': 'ThoraxTrainer: The most efficient workout on the planet',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'DKK',
#   'deadline': '2017-12-07',
#   'goal': 475000.0,
#   'launched': '2017-11-07 17:07:56',
#   'pledged': 515385.0,
#   'state': 'successful',
#   'backers': 69.0,
#   'country': 'DK',
#   'usd pledged': 18887.06957235,
#   'usd_pledged_real': 81320.51059532637},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db2194'),
#   'ID': 726969634,
#   'name': 'Sails of Glory - Miniatures Ship Combat',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-04-16',
#   'goal': 30000.0,
#   'launched': '2013-03-05 08:54:47',
#   'pledged': 276745.0,
#   'state': 'successful',
#   'backers': 1183.0,
#   'country': 'US',
#   'usd pledged': 276745.0,
#   'usd_pledged_real': 276745.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db223b'),
#   'ID': 1587924529,
#   'name': 'The Temperfect Mug: Coffee and Tea at The Perfect Temp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-01-01',
#   'goal': 23500.0,
#   'launched': '2013-11-24 23:26:14',
#   'pledged': 269271.01,
#   'state': 'successful',
#   'backers': 4903.0,
#   'country': 'US',
#   'usd pledged': 269271.01,
#   'usd_pledged_real': 269271.01},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db2350'),
#   'ID': 1577555280,
#   'name': 'SMACH Z - The Handheld Gaming PC',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-11-19',
#   'goal': 250000.0,
#   'launched': '2016-10-18 18:23:57',
#   'pledged': 474530.21,
#   'state': 'successful',
#   'backers': 1293.0,
#   'country': 'ES',
#   'usd pledged': 293522.14698456,
#   'usd_pledged_real': 502621.7389922785},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db2743'),
#   'ID': 1236208134,
#   'name': 'icebreaker - ice cubes made easy',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'DKK',
#   'deadline': '2015-10-30',
#   'goal': 200000.0,
#   'launched': '2015-09-15 22:29:36',
#   'pledged': 664222.99,
#   'state': 'successful',
#   'backers': 1786.0,
#   'country': 'DK',
#   'usd pledged': 100992.123268275,
#   'usd_pledged_real': 98121.39776051053},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db285e'),
#   'ID': 163369522,
#   'name': 'Masters Of Anatomy',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'CAD',
#   'deadline': '2013-11-20',
#   'goal': 20000.0,
#   'launched': '2013-10-11 17:59:42',
#   'pledged': 532614.11,
#   'state': 'successful',
#   'backers': 6974.0,
#   'country': 'CA',
#   'usd pledged': 511950.754400888,
#   'usd_pledged_real': 505278.54093539505},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db28ce'),
#   'ID': 23978536,
#   'name': 'RevolCam: The Multi-Lens Photo Revolution for Smartphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-11-13',
#   'goal': 50000.0,
#   'launched': '2017-09-25 05:06:25',
#   'pledged': 1195487.0,
#   'state': 'successful',
#   'backers': 4337.0,
#   'country': 'HK',
#   'usd pledged': 13695.122581200001,
#   'usd_pledged_real': 153030.1711447626},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db297b'),
#   'ID': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': '2012-08-15 21:20:10',
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162.0,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db29b4'),
#   'ID': 1253238644,
#   'name': 'Volt Planner - Reach Your Goals in 2017',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-10-25',
#   'goal': 10000.0,
#   'launched': '2016-09-08 23:07:05',
#   'pledged': 249563.22,
#   'state': 'successful',
#   'backers': 7450.0,
#   'country': 'US',
#   'usd pledged': 64953.0,
#   'usd_pledged_real': 249563.22},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db29e2'),
#   'ID': 1572015807,
#   'name': "Aeon's End: War Eternal",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-21',
#   'goal': 30000.0,
#   'launched': '2017-03-21 16:15:57',
#   'pledged': 434703.0,
#   'state': 'successful',
#   'backers': 3890.0,
#   'country': 'US',
#   'usd pledged': 201364.0,
#   'usd_pledged_real': 434703.0},
#  {'_id': ObjectId('5fc28b87a366e0e4b8db2a1d'),
#   'ID': 1497942355,
#   'name': 'XERISCOPE: The Orbiting Mechanical Automatic Watch by XERIC',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-12-21',
#   'goal': 40000.0,
#   'launched': '2013-11-06 15:21:46',
#   'pledged': 444370.38,
#   'state': 'successful',
#   'backers': 1148.0,
#   'country': 'US',
#   'usd pledged': 444370.38,
#   'usd_pledged_real': 444370.38},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2abb'),
#   'ID': 849393182,
#   'name': 'Mutant: Maskinarium',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'SEK',
#   'deadline': '2015-10-23',
#   'goal': 50000.0,
#   'launched': '2015-09-25 08:52:09',
#   'pledged': 488369.0,
#   'state': 'successful',
#   'backers': 746.0,
#   'country': 'SE',
#   'usd pledged': 58031.99455473,
#   'usd_pledged_real': 57537.76007917246},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2ad3'),
#   'ID': 1709793760,
#   'name': 'Canary in a Coal Mine',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-23',
#   'goal': 50000.0,
#   'launched': '2013-10-22 18:44:25',
#   'pledged': 212962.22,
#   'state': 'successful',
#   'backers': 2593.0,
#   'country': 'US',
#   'usd pledged': 212962.22,
#   'usd_pledged_real': 212962.22},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2c53'),
#   'ID': 851609835,
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-02-03',
#   'goal': 200000.0,
#   'launched': '2013-01-04 00:27:43',
#   'pledged': 204680.93,
#   'state': 'successful',
#   'backers': 2681.0,
#   'country': 'US',
#   'usd pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2c67'),
#   'ID': 474451095,
#   'name': 'The Journey Down',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'SEK',
#   'deadline': '2015-10-31',
#   'goal': 300000.0,
#   'launched': '2015-10-01 14:14:19',
#   'pledged': 409237.0,
#   'state': 'successful',
#   'backers': 1389.0,
#   'country': 'SE',
#   'usd pledged': 48764.25122115,
#   'usd_pledged_real': 47378.554228026296},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2d56'),
#   'ID': 271631066,
#   'name': 'MYTH: Journeyman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-29',
#   'goal': 80000.0,
#   'launched': '2015-03-09 16:58:49',
#   'pledged': 972886.0,
#   'state': 'successful',
#   'backers': 4739.0,
#   'country': 'US',
#   'usd pledged': 972886.0,
#   'usd_pledged_real': 972886.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2d6b'),
#   'ID': 874722536,
#   'name': 'The ultimate sleep sanctuary: Kokoon EEG headphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-10',
#   'goal': 100000.0,
#   'launched': '2015-05-11 17:00:32',
#   'pledged': 1936825.0,
#   'state': 'successful',
#   'backers': 8489.0,
#   'country': 'US',
#   'usd pledged': 1936825.0,
#   'usd_pledged_real': 1936825.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2e72'),
#   'ID': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': '2014-07-15 08:19:05',
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657.0,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db2e7f'),
#   'ID': 121842661,
#   'name': 'Pixy (CMUcam5): a fast, easy-to-use vision sensor',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-09-14',
#   'goal': 25000.0,
#   'launched': '2013-08-15 08:15:31',
#   'pledged': 274352.11,
#   'state': 'successful',
#   'backers': 2802.0,
#   'country': 'US',
#   'usd pledged': 274352.11,
#   'usd_pledged_real': 274352.11},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db30e7'),
#   'ID': 956834760,
#   'name': 'Zerpico - Carbon Fiber Sunglasses',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'SEK',
#   'deadline': '2016-04-05',
#   'goal': 85000.0,
#   'launched': '2016-03-01 16:09:02',
#   'pledged': 269580.0,
#   'state': 'successful',
#   'backers': 375.0,
#   'country': 'SE',
#   'usd pledged': 31483.7737392,
#   'usd_pledged_real': 32963.646812829385},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db32a0'),
#   'ID': 1540631907,
#   'name': 'Dominus Playing Cards',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'DKK',
#   'deadline': '2016-06-02',
#   'goal': 70000.0,
#   'launched': '2016-05-10 23:12:40',
#   'pledged': 297051.0,
#   'state': 'successful',
#   'backers': 968.0,
#   'country': 'DK',
#   'usd pledged': 45526.08972918,
#   'usd_pledged_real': 44544.73202771197},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3328'),
#   'ID': 1581905668,
#   'name': 'Ghost S1 MkII',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'SEK',
#   'deadline': '2017-12-29',
#   'goal': 2000000.0,
#   'launched': '2017-11-29 21:03:22',
#   'pledged': 2588996.65,
#   'state': 'successful',
#   'backers': 1260.0,
#   'country': 'SE',
#   'usd pledged': 142863.1627491,
#   'usd_pledged_real': 315423.56846978556},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db340a'),
#   'ID': 1349593857,
#   'name': 'Reissue of the 1975 NASA Graphics Standards Manual.',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-05',
#   'goal': 158000.0,
#   'launched': '2015-09-01 05:56:35',
#   'pledged': 941966.92,
#   'state': 'successful',
#   'backers': 8798.0,
#   'country': 'US',
#   'usd pledged': 941966.92,
#   'usd_pledged_real': 941966.92},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db34a4'),
#   'ID': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': '2014-01-14 19:03:30',
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824.0,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3607'),
#   'ID': 701011082,
#   'name': 'Efter Rallarsving',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'SEK',
#   'deadline': '2016-12-24',
#   'goal': 290000.0,
#   'launched': '2016-11-21 14:39:33',
#   'pledged': 307930.0,
#   'state': 'successful',
#   'backers': 376.0,
#   'country': 'SE',
#   'usd pledged': 4302.196299600001,
#   'usd_pledged_real': 33979.60760080333},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db37d0'),
#   'ID': 197928689,
#   'name': 'Fugitive',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-10',
#   'goal': 5000.0,
#   'launched': '2016-06-15 17:20:41',
#   'pledged': 228004.46,
#   'state': 'successful',
#   'backers': 7514.0,
#   'country': 'US',
#   'usd pledged': 184336.46,
#   'usd_pledged_real': 228004.46},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db37fb'),
#   'ID': 1067930555,
#   'name': 'Radian 2: Time Lapse, Motion, and Wireless Camera Control',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-05',
#   'goal': 153471.0,
#   'launched': '2015-05-07 18:58:56',
#   'pledged': 272238.0,
#   'state': 'successful',
#   'backers': 916.0,
#   'country': 'US',
#   'usd pledged': 272238.0,
#   'usd_pledged_real': 272238.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3865'),
#   'ID': 726158562,
#   'name': 'The Ultimate Sleep Travel Solution - NodPod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-09',
#   'goal': 20000.0,
#   'launched': '2016-07-26 16:59:51',
#   'pledged': 307274.0,
#   'state': 'successful',
#   'backers': 7280.0,
#   'country': 'US',
#   'usd pledged': 485.0,
#   'usd_pledged_real': 307274.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db386f'),
#   'ID': 367168138,
#   'name': 'The Opera di Firenze presents: Opera for Everybody',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2016-07-15',
#   'goal': 300000.0,
#   'launched': '2016-05-31 14:03:04',
#   'pledged': 322202.0,
#   'state': 'successful',
#   'backers': 426.0,
#   'country': 'IT',
#   'usd pledged': 87567.08415625,
#   'usd_pledged_real': 358548.01197378227},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db395c'),
#   'ID': 350259914,
#   'name': "Notion: Be home, even when you're not.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-16',
#   'goal': 50000.0,
#   'launched': '2014-09-16 17:54:46',
#   'pledged': 281655.51,
#   'state': 'successful',
#   'backers': 1338.0,
#   'country': 'US',
#   'usd pledged': 281655.51,
#   'usd_pledged_real': 281655.51},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db39e3'),
#   'ID': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': '2015-09-17 16:39:03',
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239.0,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3a63'),
#   'ID': 867411036,
#   'name': 'The Duchess - A Gaming Table from BoardGameTables.com',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-13',
#   'goal': 40000.0,
#   'launched': '2016-06-09 15:43:47',
#   'pledged': 2592231.77,
#   'state': 'successful',
#   'backers': 3364.0,
#   'country': 'US',
#   'usd pledged': 1570447.77,
#   'usd_pledged_real': 2592231.77},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3a92'),
#   'ID': 545788185,
#   'name': "World's First And Only Complete Weather Camera System",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-08-30',
#   'goal': 80000.0,
#   'launched': '2016-07-20 22:37:35',
#   'pledged': 680826.0,
#   'state': 'successful',
#   'backers': 2966.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 680826.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3ac0'),
#   'ID': 2063922972,
#   'name': 'Phantom Ice Maker | Seven Clear, Slow-Melting Ice Shapes',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-11-25',
#   'goal': 50000.0,
#   'launched': '2017-10-25 16:05:08',
#   'pledged': 424615.0,
#   'state': 'successful',
#   'backers': 3015.0,
#   'country': 'US',
#   'usd pledged': 155376.0,
#   'usd_pledged_real': 424615.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3b51'),
#   'ID': 1700025657,
#   'name': 'Skriware - Home 3D Printing for everyone',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'SEK',
#   'deadline': '2016-01-20',
#   'goal': 440000.0,
#   'launched': '2015-11-25 19:06:49',
#   'pledged': 528140.86,
#   'state': 'successful',
#   'backers': 207.0,
#   'country': 'SE',
#   'usd pledged': 60569.211322885196,
#   'usd_pledged_real': 61551.29188275741},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3b94'),
#   'ID': 422835962,
#   'name': 'HUDWAY CAST. Keep your eyes on the road!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-09-29',
#   'goal': 100000.0,
#   'launched': '2017-08-28 21:23:40',
#   'pledged': 583563.0,
#   'state': 'successful',
#   'backers': 2552.0,
#   'country': 'US',
#   'usd pledged': 142610.0,
#   'usd_pledged_real': 583563.0},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3c75'),
#   'ID': 2103108924,
#   'name': 'LIVING PLANET by Christophe Boelinger',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-12-15',
#   'goal': 8000.0,
#   'launched': '2017-11-21 20:02:38',
#   'pledged': 209815.0,
#   'state': 'successful',
#   'backers': 2495.0,
#   'country': 'FR',
#   'usd pledged': 55254.709867699996,
#   'usd_pledged_real': 247706.6927971855},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3d9a'),
#   'ID': 1478679250,
#   'name': 'THE AAL WATCH',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'DKK',
#   'deadline': '2015-12-02',
#   'goal': 200000.0,
#   'launched': '2015-11-01 20:03:10',
#   'pledged': 224689.0,
#   'state': 'successful',
#   'backers': 189.0,
#   'country': 'DK',
#   'usd pledged': 33114.29408315,
#   'usd_pledged_real': 32834.38792360188},
#  {'_id': ObjectId('5fc28b88a366e0e4b8db3de2'),
#   'ID': 2128094718,
#   'name': 'Code Monkey Save World',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-05-15',
#   'goal': 39000.0,
#   'launched': '2013-04-15 15:18:36',
#   'pledged': 340270.07,
#   'state': 'successful',
#   'backers': 8452.0,
#   'country': 'US',
#   'usd pledged': 340270.07,
#   'usd_pledged_real': 340270.07},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db3e1b'),
#   'ID': 1253340997,
#   'name': 'Worldï¿½s first roast-grind-brew coffee machine',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 135000.0,
#   'launched': '2013-11-12 15:00:06',
#   'pledged': 681461.0,
#   'state': 'successful',
#   'backers': 2254.0,
#   'country': 'US',
#   'usd pledged': 681461.0,
#   'usd_pledged_real': 681461.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db3e66'),
#   'ID': 645756120,
#   'name': 'Masters Of Anatomy Book 2 & 3',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'CAD',
#   'deadline': '2015-12-17',
#   'goal': 20000.0,
#   'launched': '2015-11-17 17:56:33',
#   'pledged': 266405.0,
#   'state': 'successful',
#   'backers': 2868.0,
#   'country': 'CA',
#   'usd pledged': 200031.5369312,
#   'usd_pledged_real': 190889.22327314413},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db3ec4'),
#   'ID': 1036153335,
#   'name': 'MagSphere & MagBounce Flash Diffusers - by MagMod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 50000.0,
#   'launched': '2014-10-29 15:10:02',
#   'pledged': 310348.0,
#   'state': 'successful',
#   'backers': 2322.0,
#   'country': 'US',
#   'usd pledged': 310348.0,
#   'usd_pledged_real': 310348.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db3f65'),
#   'ID': 731137767,
#   'name': 'Finex Cast Iron Skillet: A Beloved Classic Updated',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-18',
#   'goal': 25000.0,
#   'launched': '2013-10-17 02:51:37',
#   'pledged': 211027.66,
#   'state': 'successful',
#   'backers': 1558.0,
#   'country': 'US',
#   'usd pledged': 211027.66,
#   'usd_pledged_real': 211027.66},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db3f94'),
#   'ID': 459943590,
#   'name': 'Ctrl+Alt+Del 1.0: The Box Set',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2015-06-03',
#   'goal': 150000.0,
#   'launched': '2015-05-04 06:05:45',
#   'pledged': 665725.94,
#   'state': 'successful',
#   'backers': 5553.0,
#   'country': 'US',
#   'usd pledged': 665725.94,
#   'usd_pledged_real': 665725.94},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db3fea'),
#   'ID': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 350000.0,
#   'launched': '2013-07-07 23:34:52',
#   'pledged': 365670.0,
#   'state': 'successful',
#   'backers': 1785.0,
#   'country': 'US',
#   'usd pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db402b'),
#   'ID': 46151486,
#   'name': 'Vanguard of War - Archon Studio',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-02-01',
#   'goal': 45000.0,
#   'launched': '2017-01-10 18:00:16',
#   'pledged': 269111.0,
#   'state': 'successful',
#   'backers': 1851.0,
#   'country': 'US',
#   'usd pledged': 164672.0,
#   'usd_pledged_real': 269111.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4137'),
#   'ID': 1262190409,
#   'name': 'LUNAR MISSION ONE: A new lunar mission for everyone.',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-12-18',
#   'goal': 600000.0,
#   'launched': '2014-11-19 00:59:59',
#   'pledged': 672447.28,
#   'state': 'successful',
#   'backers': 7297.0,
#   'country': 'GB',
#   'usd pledged': 1057094.292448,
#   'usd_pledged_real': 1052244.3589021377},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db420c'),
#   'ID': 926038987,
#   'name': "H-Hour: World's Elite",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 200000.0,
#   'launched': '2013-06-07 23:00:45',
#   'pledged': 252662.28,
#   'state': 'successful',
#   'backers': 2772.0,
#   'country': 'US',
#   'usd pledged': 252662.28,
#   'usd_pledged_real': 252662.28},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db43d3'),
#   'ID': 1911751690,
#   'name': 'Dungeon of Doom: Handcrafted Game Terrain by Dwarven Forge',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 100000.0,
#   'launched': '2017-06-17 17:00:09',
#   'pledged': 3055118.0,
#   'state': 'successful',
#   'backers': 2897.0,
#   'country': 'US',
#   'usd pledged': 1397310.0,
#   'usd_pledged_real': 3055118.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db44fc'),
#   'ID': 559646778,
#   'name': 'Little Sun Charge: a solar phone charger by Olafur Eliasson',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-10-05',
#   'goal': 50000.0,
#   'launched': '2015-09-02 12:11:05',
#   'pledged': 265448.0,
#   'state': 'successful',
#   'backers': 2080.0,
#   'country': 'DE',
#   'usd pledged': 299133.41490752,
#   'usd_pledged_real': 301600.89986706513},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4577'),
#   'ID': 1204797852,
#   'name': 'Aircon Watch:The World First Personal Air-Conditioning Watch',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-10-12',
#   'goal': 38000.0,
#   'launched': '2017-09-12 19:01:28',
#   'pledged': 2320666.0,
#   'state': 'successful',
#   'backers': 3251.0,
#   'country': 'HK',
#   'usd pledged': 14987.9710935,
#   'usd_pledged_real': 297224.05799328873},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4659'),
#   'ID': 1310046506,
#   'name': 'Click - The First Watch Band Adapter for Apple Watch!',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-18',
#   'goal': 30000.0,
#   'launched': '2015-03-18 23:35:57',
#   'pledged': 216436.0,
#   'state': 'successful',
#   'backers': 5538.0,
#   'country': 'US',
#   'usd pledged': 216436.0,
#   'usd_pledged_real': 216436.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db46bd'),
#   'ID': 443600622,
#   'name': 'Passion Planner: Get One, Give One',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-24',
#   'goal': 15000.0,
#   'launched': '2015-10-13 19:00:52',
#   'pledged': 706287.0,
#   'state': 'successful',
#   'backers': 16335.0,
#   'country': 'US',
#   'usd pledged': 706287.0,
#   'usd_pledged_real': 706287.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db46d0'),
#   'ID': 22304643,
#   'name': 'Kill Doctor Lucky',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-14',
#   'goal': 40000.0,
#   'launched': '2015-10-13 21:01:01',
#   'pledged': 210086.5,
#   'state': 'successful',
#   'backers': 2711.0,
#   'country': 'US',
#   'usd pledged': 210086.5,
#   'usd_pledged_real': 210086.5},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db486d'),
#   'ID': 1638382067,
#   'name': 'Be. | The First Battery-Free, Powered Toothbrush',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-12-09',
#   'goal': 30000.0,
#   'launched': '2017-10-24 18:45:41',
#   'pledged': 423143.01,
#   'state': 'successful',
#   'backers': 5340.0,
#   'country': 'US',
#   'usd pledged': 17925.0,
#   'usd_pledged_real': 423143.01},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4880'),
#   'ID': 1026598212,
#   'name': 'Numenera: Into the Ninth World',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 20000.0,
#   'launched': '2015-08-05 18:04:36',
#   'pledged': 417560.0,
#   'state': 'successful',
#   'backers': 3317.0,
#   'country': 'US',
#   'usd pledged': 417560.0,
#   'usd_pledged_real': 417560.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db48a1'),
#   'ID': 248979774,
#   'name': 'ZRRO - Play 300,000 touch games on your TV!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-31',
#   'goal': 200000.0,
#   'launched': '2015-02-17 19:20:19',
#   'pledged': 200392.0,
#   'state': 'successful',
#   'backers': 762.0,
#   'country': 'US',
#   'usd pledged': 200392.0,
#   'usd_pledged_real': 200392.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db48c5'),
#   'ID': 1636168806,
#   'name': 'StoneTether - The Smallest Tracking Device at Long Range',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 15000.0,
#   'launched': '2014-11-03 17:39:21',
#   'pledged': 366199.0,
#   'state': 'successful',
#   'backers': 6927.0,
#   'country': 'US',
#   'usd pledged': 366199.0,
#   'usd_pledged_real': 366199.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db48da'),
#   'ID': 1616845470,
#   'name': 'Woobo: A Smart Companion for Curious Kids',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-10-21',
#   'goal': 50000.0,
#   'launched': '2017-09-21 16:47:51',
#   'pledged': 221642.0,
#   'state': 'successful',
#   'backers': 1425.0,
#   'country': 'US',
#   'usd pledged': 83235.0,
#   'usd_pledged_real': 221642.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db49ba'),
#   'ID': 415727459,
#   'name': 'FormBox: A Desktop Vacuum Former That Makes Beautiful Things',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-03',
#   'goal': 50000.0,
#   'launched': '2016-05-02 19:22:23',
#   'pledged': 588775.55,
#   'state': 'successful',
#   'backers': 1745.0,
#   'country': 'US',
#   'usd pledged': 588775.55,
#   'usd_pledged_real': 588775.55},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4a7f'),
#   'ID': 1609451282,
#   'name': 'The Universe in a Sphere (Relaunch)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-01-02',
#   'goal': 11000.0,
#   'launched': '2016-11-30 09:03:34',
#   'pledged': 306970.0,
#   'state': 'successful',
#   'backers': 3663.0,
#   'country': 'DE',
#   'usd pledged': 2754.16092174,
#   'usd_pledged_real': 325049.2386539317},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4aa1'),
#   'ID': 815224727,
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-01-07',
#   'goal': 250000.0,
#   'launched': '2013-12-04 18:56:58',
#   'pledged': 310225.01,
#   'state': 'successful',
#   'backers': 2026.0,
#   'country': 'US',
#   'usd pledged': 310225.01,
#   'usd_pledged_real': 310225.01},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4b7c'),
#   'ID': 1504572566,
#   'name': 'Novo - the smartest radiator valve',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2017-12-26',
#   'goal': 25000.0,
#   'launched': '2017-11-16 16:32:07',
#   'pledged': 208661.0,
#   'state': 'successful',
#   'backers': 1677.0,
#   'country': 'GB',
#   'usd pledged': 72720.53368146,
#   'usd_pledged_real': 282054.36677976185},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4df1'),
#   'ID': 926266608,
#   'name': 'Modbook Pro X ï¿½ 15.4" Retina Quad-Core Mac OS X Tablet',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-07',
#   'goal': 150000.0,
#   'launched': '2014-07-30 18:57:35',
#   'pledged': 318244.34,
#   'state': 'successful',
#   'backers': 331.0,
#   'country': 'US',
#   'usd pledged': 318244.34,
#   'usd_pledged_real': 318244.34},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4e05'),
#   'ID': 697445050,
#   'name': 'Remix IO - A 4K, Nougat-powered, All-in-One device',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-19',
#   'goal': 250000.0,
#   'launched': '2016-10-20 16:57:37',
#   'pledged': 598268.0,
#   'state': 'successful',
#   'backers': 4435.0,
#   'country': 'US',
#   'usd pledged': 233222.0,
#   'usd_pledged_real': 598268.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4f83'),
#   'ID': 849119531,
#   'name': 'Fief - France 1429',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-11',
#   'goal': 20000.0,
#   'launched': '2013-12-28 20:01:26',
#   'pledged': 408519.36,
#   'state': 'successful',
#   'backers': 4021.0,
#   'country': 'US',
#   'usd pledged': 408519.36,
#   'usd_pledged_real': 408519.36},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db4ff2'),
#   'ID': 776266348,
#   'name': 'Posthuman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-24',
#   'goal': 27000.0,
#   'launched': '2015-03-25 22:52:43',
#   'pledged': 346071.0,
#   'state': 'successful',
#   'backers': 5323.0,
#   'country': 'US',
#   'usd pledged': 346071.0,
#   'usd_pledged_real': 346071.0},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db502d'),
#   'ID': 1942255469,
#   'name': 'Luminoodle: Versatile USB Lighting Solution',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-15',
#   'goal': 10000.0,
#   'launched': '2015-09-15 16:00:10',
#   'pledged': 388464.1,
#   'state': 'successful',
#   'backers': 6768.0,
#   'country': 'US',
#   'usd pledged': 388464.1,
#   'usd_pledged_real': 388464.1},
#  {'_id': ObjectId('5fc28b89a366e0e4b8db5101'),
#   'ID': 1192070348,
#   'name': 'Glowdeck - A companion for your smartphone.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-01',
#   'goal': 30000.0,
#   'launched': '2014-03-18 20:52:29',
#   'pledged': 209669.0,
#   'state': 'successful',
#   'backers': 956.0,
#   'country': 'US',
#   'usd pledged': 209669.0,
#   'usd_pledged_real': 209669.0},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db51f5'),
#   'ID': 1967287711,
#   'name': 'tinyTesla: the Little Singing Tesla Coil Anyone Can Build',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-15',
#   'goal': 20000.0,
#   'launched': '2014-07-16 19:48:29',
#   'pledged': 336271.05,
#   'state': 'successful',
#   'backers': 1568.0,
#   'country': 'US',
#   'usd pledged': 336271.05,
#   'usd_pledged_real': 336271.05},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db522f'),
#   'ID': 2137602357,
#   'name': 'ZUNGLE : Wear the Beats',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 50000.0,
#   'launched': '2016-06-16 16:41:54',
#   'pledged': 1947035.0,
#   'state': 'successful',
#   'backers': 11349.0,
#   'country': 'US',
#   'usd pledged': 207044.0,
#   'usd_pledged_real': 1947035.0},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db52cc'),
#   'ID': 1016583750,
#   'name': 'colorspike - create in color',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-11-17',
#   'goal': 120000.0,
#   'launched': '2017-10-03 17:06:22',
#   'pledged': 355212.0,
#   'state': 'successful',
#   'backers': 663.0,
#   'country': 'US',
#   'usd pledged': 64001.0,
#   'usd_pledged_real': 355212.0},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5301'),
#   'ID': 1288353288,
#   'name': 'ORION4Sight: Sunglasses On Steroids',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 9000.0,
#   'launched': '2014-08-12 18:37:49',
#   'pledged': 348449.0,
#   'state': 'successful',
#   'backers': 2881.0,
#   'country': 'US',
#   'usd pledged': 348449.0,
#   'usd_pledged_real': 348449.0},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db54ba'),
#   'ID': 1669948790,
#   'name': 'Unknown Armies Third Edition Roleplaying Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 40000.0,
#   'launched': '2016-03-30 21:33:25',
#   'pledged': 266084.45,
#   'state': 'successful',
#   'backers': 2819.0,
#   'country': 'US',
#   'usd pledged': 266084.45,
#   'usd_pledged_real': 266084.45},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db55d5'),
#   'ID': 208387231,
#   'name': 'Battalion 1944 (PC/XB1/PS4)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2016-03-03',
#   'goal': 100000.0,
#   'launched': '2016-02-02 13:14:44',
#   'pledged': 317281.67,
#   'state': 'successful',
#   'backers': 10096.0,
#   'country': 'GB',
#   'usd pledged': 452369.652297656,
#   'usd_pledged_real': 449203.85944048024},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db55e1'),
#   'ID': 1123922487,
#   'name': 'Buddy. The Dog Collar Reimagined.',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'AUD',
#   'deadline': '2015-09-02',
#   'goal': 385000.0,
#   'launched': '2015-08-03 17:15:55',
#   'pledged': 262654.0,
#   'state': 'failed',
#   'backers': 973.0,
#   'country': 'AU',
#   'usd pledged': 191861.93375524,
#   'usd_pledged_real': 183430.4071513374},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db55f8'),
#   'ID': 123593551,
#   'name': 'Moral Superpower: A book on immigration by Tino Sanandaji.',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'SEK',
#   'deadline': '2015-01-04',
#   'goal': 400000.0,
#   'launched': '2014-12-14 21:45:05',
#   'pledged': 632205.0,
#   'state': 'successful',
#   'backers': 1344.0,
#   'country': 'SE',
#   'usd pledged': 83742.74042085,
#   'usd_pledged_real': 78709.80191979682},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db562a'),
#   'ID': 474144967,
#   'name': 'Crowfall - Throne War PC MMO',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-26',
#   'goal': 800000.0,
#   'launched': '2015-02-24 14:00:26',
#   'pledged': 1766204.58,
#   'state': 'successful',
#   'backers': 16936.0,
#   'country': 'US',
#   'usd pledged': 1766204.58,
#   'usd_pledged_real': 1766204.58},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5639'),
#   'ID': 423350076,
#   'name': 'BIKI: First Bionic Wireless Underwater Fish Drone',
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-07-21',
#   'goal': 20000.0,
#   'launched': '2017-05-22 18:17:17',
#   'pledged': 222232.0,
#   'state': 'successful',
#   'backers': 411.0,
#   'country': 'US',
#   'usd pledged': 41313.0,
#   'usd_pledged_real': 222232.0},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db56b7'),
#   'ID': 969897193,
#   'name': 'Create wide-angle Bubble Bokeh: Trioplan 35+ Fine Art Lens',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2017-04-13',
#   'goal': 50000.0,
#   'launched': '2017-03-09 16:00:22',
#   'pledged': 595893.23,
#   'state': 'successful',
#   'backers': 774.0,
#   'country': 'US',
#   'usd pledged': 239730.21,
#   'usd_pledged_real': 595893.23},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5716'),
#   'ID': 606522341,
#   'name': 'Gloom of Kilforth: A Fantasy Quest Game Expansions',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2017-11-01',
#   'goal': 27000.0,
#   'launched': '2017-09-29 10:05:28',
#   'pledged': 207859.0,
#   'state': 'successful',
#   'backers': 3034.0,
#   'country': 'GB',
#   'usd pledged': 113014.65634382,
#   'usd_pledged_real': 272484.03969429625},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5a16'),
#   'ID': 1317644491,
#   'name': "Remix Mini - The World's First True Android PC.",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-29',
#   'goal': 50000.0,
#   'launched': '2015-07-15 14:55:55',
#   'pledged': 1647155.12,
#   'state': 'successful',
#   'backers': 21975.0,
#   'country': 'US',
#   'usd pledged': 1647155.12,
#   'usd_pledged_real': 1647155.12},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5b2c'),
#   'ID': 443272157,
#   'name': 'Zafirro. Sapphire Blade Razor.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-08-10',
#   'goal': 1000000.0,
#   'launched': '2016-07-11 17:00:34',
#   'pledged': 431484.0,
#   'state': 'failed',
#   'backers': 3404.0,
#   'country': 'US',
#   'usd pledged': 51347.0,
#   'usd_pledged_real': 431484.0},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5c33'),
#   'ID': 1503876316,
#   'name': 'Tricksters - Meet the mischievous Annukuh',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'MXN',
#   'deadline': '2016-12-16',
#   'goal': 40000.0,
#   'launched': '2016-11-15 16:50:41',
#   'pledged': 429900.0,
#   'state': 'successful',
#   'backers': 703.0,
#   'country': 'MX',
#   'usd pledged': 1578.1284632000006,
#   'usd_pledged_real': 21115.968367798025},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5c9c'),
#   'ID': 434718627,
#   'name': 'Little Witch Academia 2',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-08',
#   'goal': 150000.0,
#   'launched': '2013-07-09 05:31:42',
#   'pledged': 625518.12,
#   'state': 'successful',
#   'backers': 7938.0,
#   'country': 'US',
#   'usd pledged': 625518.12,
#   'usd_pledged_real': 625518.12},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5cb4'),
#   'ID': 375709459,
#   'name': 'Dead State: The Zombie Survival RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-05',
#   'goal': 150000.0,
#   'launched': '2012-06-05 23:31:17',
#   'pledged': 332635.58,
#   'state': 'successful',
#   'backers': 10096.0,
#   'country': 'US',
#   'usd pledged': 332635.58,
#   'usd_pledged_real': 332635.58},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5ccb'),
#   'ID': 943689001,
#   'name': 'Dobot M1: Pro Robotic Arm for Makers and Businesses',
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-01-12',
#   'goal': 100000.0,
#   'launched': '2016-11-28 14:09:18',
#   'pledged': 506351.12,
#   'state': 'successful',
#   'backers': 352.0,
#   'country': 'US',
#   'usd pledged': 67790.0,
#   'usd_pledged_real': 506351.12},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5e5d'),
#   'ID': 2123383062,
#   'name': 'Ulo',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-04',
#   'goal': 199000.0,
#   'launched': '2015-10-05 15:48:03',
#   'pledged': 1618869.12,
#   'state': 'successful',
#   'backers': 8330.0,
#   'country': 'FR',
#   'usd pledged': 1815079.1817613998,
#   'usd_pledged_real': 1764896.6705187191},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db5f67'),
#   'ID': 1104229032,
#   'name': 'Ragnarok Playing Cards',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'DKK',
#   'deadline': '2017-11-15',
#   'goal': 115000.0,
#   'launched': '2017-10-17 18:21:04',
#   'pledged': 629351.0,
#   'state': 'successful',
#   'backers': 1669.0,
#   'country': 'DK',
#   'usd pledged': 26586.99117432,
#   'usd_pledged_real': 99760.80271375582},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db6043'),
#   'ID': 1580603288,
#   'name': "Illustrator's Guidebook",
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'SEK',
#   'deadline': '2015-10-31',
#   'goal': 170000.0,
#   'launched': '2015-09-30 17:46:16',
#   'pledged': 1688094.75,
#   'state': 'successful',
#   'backers': 2836.0,
#   'country': 'SE',
#   'usd pledged': 199870.654733265,
#   'usd_pledged_real': 195435.624479022},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db62c0'),
#   'ID': 504955583,
#   'name': 'Wiral LITE | The Easy Cable Cam, For Impossible Film Shots',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-11-16',
#   'goal': 30000.0,
#   'launched': '2017-10-17 17:55:55',
#   'pledged': 1055480.02,
#   'state': 'successful',
#   'backers': 4126.0,
#   'country': 'US',
#   'usd pledged': 143654.96,
#   'usd_pledged_real': 1055480.02},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db63b1'),
#   'ID': 1641552959,
#   'name': 'Dungeon Dice: THE LOST KING and Boxed Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-05-12',
#   'goal': 10000.0,
#   'launched': '2017-04-11 16:41:08',
#   'pledged': 252810.6,
#   'state': 'successful',
#   'backers': 2012.0,
#   'country': 'US',
#   'usd pledged': 86053.0,
#   'usd_pledged_real': 252810.6},
#  {'_id': ObjectId('5fc28b8aa366e0e4b8db63d5'),
#   'ID': 318711594,
#   'name': 'Minimalist Bags Without The Luxury Markup',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-04-25',
#   'goal': 400000.0,
# ...
#   'goal': 500000.0,
#   'launched': '2015-09-17 16:39:03',
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239.0,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b5e46'),
#   'ID': 867411036,
#   'name': 'The Duchess - A Gaming Table from BoardGameTables.com',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-13',
#   'goal': 40000.0,
#   'launched': '2016-06-09 15:43:47',
#   'pledged': 2592231.77,
#   'state': 'successful',
#   'backers': 3364.0,
#   'country': 'US',
#   'usd pledged': 1570447.77,
#   'usd_pledged_real': 2592231.77},
#  {'_id': ObjectId('5fc28bd5133d77838a7b5e75'),
#   'ID': 545788185,
#   'name': "World's First And Only Complete Weather Camera System",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-08-30',
#   'goal': 80000.0,
#   'launched': '2016-07-20 22:37:35',
#   'pledged': 680826.0,
#   'state': 'successful',
#   'backers': 2966.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 680826.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b5ea3'),
#   'ID': 2063922972,
#   'name': 'Phantom Ice Maker | Seven Clear, Slow-Melting Ice Shapes',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-11-25',
#   'goal': 50000.0,
#   'launched': '2017-10-25 16:05:08',
#   'pledged': 424615.0,
#   'state': 'successful',
#   'backers': 3015.0,
#   'country': 'US',
#   'usd pledged': 155376.0,
#   'usd_pledged_real': 424615.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b5f34'),
#   'ID': 1700025657,
#   'name': 'Skriware - Home 3D Printing for everyone',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'SEK',
#   'deadline': '2016-01-20',
#   'goal': 440000.0,
#   'launched': '2015-11-25 19:06:49',
#   'pledged': 528140.86,
#   'state': 'successful',
#   'backers': 207.0,
#   'country': 'SE',
#   'usd pledged': 60569.211322885196,
#   'usd_pledged_real': 61551.29188275741},
#  {'_id': ObjectId('5fc28bd5133d77838a7b5f77'),
#   'ID': 422835962,
#   'name': 'HUDWAY CAST. Keep your eyes on the road!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-09-29',
#   'goal': 100000.0,
#   'launched': '2017-08-28 21:23:40',
#   'pledged': 583563.0,
#   'state': 'successful',
#   'backers': 2552.0,
#   'country': 'US',
#   'usd pledged': 142610.0,
#   'usd_pledged_real': 583563.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b6058'),
#   'ID': 2103108924,
#   'name': 'LIVING PLANET by Christophe Boelinger',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-12-15',
#   'goal': 8000.0,
#   'launched': '2017-11-21 20:02:38',
#   'pledged': 209815.0,
#   'state': 'successful',
#   'backers': 2495.0,
#   'country': 'FR',
#   'usd pledged': 55254.709867699996,
#   'usd_pledged_real': 247706.6927971855},
#  {'_id': ObjectId('5fc28bd5133d77838a7b617d'),
#   'ID': 1478679250,
#   'name': 'THE AAL WATCH',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'DKK',
#   'deadline': '2015-12-02',
#   'goal': 200000.0,
#   'launched': '2015-11-01 20:03:10',
#   'pledged': 224689.0,
#   'state': 'successful',
#   'backers': 189.0,
#   'country': 'DK',
#   'usd pledged': 33114.29408315,
#   'usd_pledged_real': 32834.38792360188},
#  {'_id': ObjectId('5fc28bd5133d77838a7b61c5'),
#   'ID': 2128094718,
#   'name': 'Code Monkey Save World',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-05-15',
#   'goal': 39000.0,
#   'launched': '2013-04-15 15:18:36',
#   'pledged': 340270.07,
#   'state': 'successful',
#   'backers': 8452.0,
#   'country': 'US',
#   'usd pledged': 340270.07,
#   'usd_pledged_real': 340270.07},
#  {'_id': ObjectId('5fc28bd5133d77838a7b61fe'),
#   'ID': 1253340997,
#   'name': 'Worldï¿½s first roast-grind-brew coffee machine',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 135000.0,
#   'launched': '2013-11-12 15:00:06',
#   'pledged': 681461.0,
#   'state': 'successful',
#   'backers': 2254.0,
#   'country': 'US',
#   'usd pledged': 681461.0,
#   'usd_pledged_real': 681461.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b6249'),
#   'ID': 645756120,
#   'name': 'Masters Of Anatomy Book 2 & 3',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'CAD',
#   'deadline': '2015-12-17',
#   'goal': 20000.0,
#   'launched': '2015-11-17 17:56:33',
#   'pledged': 266405.0,
#   'state': 'successful',
#   'backers': 2868.0,
#   'country': 'CA',
#   'usd pledged': 200031.5369312,
#   'usd_pledged_real': 190889.22327314413},
#  {'_id': ObjectId('5fc28bd5133d77838a7b62a7'),
#   'ID': 1036153335,
#   'name': 'MagSphere & MagBounce Flash Diffusers - by MagMod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 50000.0,
#   'launched': '2014-10-29 15:10:02',
#   'pledged': 310348.0,
#   'state': 'successful',
#   'backers': 2322.0,
#   'country': 'US',
#   'usd pledged': 310348.0,
#   'usd_pledged_real': 310348.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b6348'),
#   'ID': 731137767,
#   'name': 'Finex Cast Iron Skillet: A Beloved Classic Updated',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-18',
#   'goal': 25000.0,
#   'launched': '2013-10-17 02:51:37',
#   'pledged': 211027.66,
#   'state': 'successful',
#   'backers': 1558.0,
#   'country': 'US',
#   'usd pledged': 211027.66,
#   'usd_pledged_real': 211027.66},
#  {'_id': ObjectId('5fc28bd5133d77838a7b6377'),
#   'ID': 459943590,
#   'name': 'Ctrl+Alt+Del 1.0: The Box Set',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2015-06-03',
#   'goal': 150000.0,
#   'launched': '2015-05-04 06:05:45',
#   'pledged': 665725.94,
#   'state': 'successful',
#   'backers': 5553.0,
#   'country': 'US',
#   'usd pledged': 665725.94,
#   'usd_pledged_real': 665725.94},
#  {'_id': ObjectId('5fc28bd5133d77838a7b63cd'),
#   'ID': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 350000.0,
#   'launched': '2013-07-07 23:34:52',
#   'pledged': 365670.0,
#   'state': 'successful',
#   'backers': 1785.0,
#   'country': 'US',
#   'usd pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b640e'),
#   'ID': 46151486,
#   'name': 'Vanguard of War - Archon Studio',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-02-01',
#   'goal': 45000.0,
#   'launched': '2017-01-10 18:00:16',
#   'pledged': 269111.0,
#   'state': 'successful',
#   'backers': 1851.0,
#   'country': 'US',
#   'usd pledged': 164672.0,
#   'usd_pledged_real': 269111.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b651a'),
#   'ID': 1262190409,
#   'name': 'LUNAR MISSION ONE: A new lunar mission for everyone.',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-12-18',
#   'goal': 600000.0,
#   'launched': '2014-11-19 00:59:59',
#   'pledged': 672447.28,
#   'state': 'successful',
#   'backers': 7297.0,
#   'country': 'GB',
#   'usd pledged': 1057094.292448,
#   'usd_pledged_real': 1052244.3589021377},
#  {'_id': ObjectId('5fc28bd5133d77838a7b65ef'),
#   'ID': 926038987,
#   'name': "H-Hour: World's Elite",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 200000.0,
#   'launched': '2013-06-07 23:00:45',
#   'pledged': 252662.28,
#   'state': 'successful',
#   'backers': 2772.0,
#   'country': 'US',
#   'usd pledged': 252662.28,
#   'usd_pledged_real': 252662.28},
#  {'_id': ObjectId('5fc28bd5133d77838a7b67b6'),
#   'ID': 1911751690,
#   'name': 'Dungeon of Doom: Handcrafted Game Terrain by Dwarven Forge',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 100000.0,
#   'launched': '2017-06-17 17:00:09',
#   'pledged': 3055118.0,
#   'state': 'successful',
#   'backers': 2897.0,
#   'country': 'US',
#   'usd pledged': 1397310.0,
#   'usd_pledged_real': 3055118.0},
#  {'_id': ObjectId('5fc28bd5133d77838a7b68df'),
#   'ID': 559646778,
#   'name': 'Little Sun Charge: a solar phone charger by Olafur Eliasson',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-10-05',
#   'goal': 50000.0,
#   'launched': '2015-09-02 12:11:05',
#   'pledged': 265448.0,
#   'state': 'successful',
#   'backers': 2080.0,
#   'country': 'DE',
#   'usd pledged': 299133.41490752,
#   'usd_pledged_real': 301600.89986706513},
#  {'_id': ObjectId('5fc28bd6133d77838a7b695a'),
#   'ID': 1204797852,
#   'name': 'Aircon Watch:The World First Personal Air-Conditioning Watch',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-10-12',
#   'goal': 38000.0,
#   'launched': '2017-09-12 19:01:28',
#   'pledged': 2320666.0,
#   'state': 'successful',
#   'backers': 3251.0,
#   'country': 'HK',
#   'usd pledged': 14987.9710935,
#   'usd_pledged_real': 297224.05799328873},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6a3c'),
#   'ID': 1310046506,
#   'name': 'Click - The First Watch Band Adapter for Apple Watch!',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-18',
#   'goal': 30000.0,
#   'launched': '2015-03-18 23:35:57',
#   'pledged': 216436.0,
#   'state': 'successful',
#   'backers': 5538.0,
#   'country': 'US',
#   'usd pledged': 216436.0,
#   'usd_pledged_real': 216436.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6aa0'),
#   'ID': 443600622,
#   'name': 'Passion Planner: Get One, Give One',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-24',
#   'goal': 15000.0,
#   'launched': '2015-10-13 19:00:52',
#   'pledged': 706287.0,
#   'state': 'successful',
#   'backers': 16335.0,
#   'country': 'US',
#   'usd pledged': 706287.0,
#   'usd_pledged_real': 706287.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6ab3'),
#   'ID': 22304643,
#   'name': 'Kill Doctor Lucky',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-14',
#   'goal': 40000.0,
#   'launched': '2015-10-13 21:01:01',
#   'pledged': 210086.5,
#   'state': 'successful',
#   'backers': 2711.0,
#   'country': 'US',
#   'usd pledged': 210086.5,
#   'usd_pledged_real': 210086.5},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6c50'),
#   'ID': 1638382067,
#   'name': 'Be. | The First Battery-Free, Powered Toothbrush',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-12-09',
#   'goal': 30000.0,
#   'launched': '2017-10-24 18:45:41',
#   'pledged': 423143.01,
#   'state': 'successful',
#   'backers': 5340.0,
#   'country': 'US',
#   'usd pledged': 17925.0,
#   'usd_pledged_real': 423143.01},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6c63'),
#   'ID': 1026598212,
#   'name': 'Numenera: Into the Ninth World',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 20000.0,
#   'launched': '2015-08-05 18:04:36',
#   'pledged': 417560.0,
#   'state': 'successful',
#   'backers': 3317.0,
#   'country': 'US',
#   'usd pledged': 417560.0,
#   'usd_pledged_real': 417560.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6c84'),
#   'ID': 248979774,
#   'name': 'ZRRO - Play 300,000 touch games on your TV!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-31',
#   'goal': 200000.0,
#   'launched': '2015-02-17 19:20:19',
#   'pledged': 200392.0,
#   'state': 'successful',
#   'backers': 762.0,
#   'country': 'US',
#   'usd pledged': 200392.0,
#   'usd_pledged_real': 200392.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6ca8'),
#   'ID': 1636168806,
#   'name': 'StoneTether - The Smallest Tracking Device at Long Range',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 15000.0,
#   'launched': '2014-11-03 17:39:21',
#   'pledged': 366199.0,
#   'state': 'successful',
#   'backers': 6927.0,
#   'country': 'US',
#   'usd pledged': 366199.0,
#   'usd_pledged_real': 366199.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6cbd'),
#   'ID': 1616845470,
#   'name': 'Woobo: A Smart Companion for Curious Kids',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-10-21',
#   'goal': 50000.0,
#   'launched': '2017-09-21 16:47:51',
#   'pledged': 221642.0,
#   'state': 'successful',
#   'backers': 1425.0,
#   'country': 'US',
#   'usd pledged': 83235.0,
#   'usd_pledged_real': 221642.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6d9d'),
#   'ID': 415727459,
#   'name': 'FormBox: A Desktop Vacuum Former That Makes Beautiful Things',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-03',
#   'goal': 50000.0,
#   'launched': '2016-05-02 19:22:23',
#   'pledged': 588775.55,
#   'state': 'successful',
#   'backers': 1745.0,
#   'country': 'US',
#   'usd pledged': 588775.55,
#   'usd_pledged_real': 588775.55},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6e62'),
#   'ID': 1609451282,
#   'name': 'The Universe in a Sphere (Relaunch)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-01-02',
#   'goal': 11000.0,
#   'launched': '2016-11-30 09:03:34',
#   'pledged': 306970.0,
#   'state': 'successful',
#   'backers': 3663.0,
#   'country': 'DE',
#   'usd pledged': 2754.16092174,
#   'usd_pledged_real': 325049.2386539317},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6e84'),
#   'ID': 815224727,
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-01-07',
#   'goal': 250000.0,
#   'launched': '2013-12-04 18:56:58',
#   'pledged': 310225.01,
#   'state': 'successful',
#   'backers': 2026.0,
#   'country': 'US',
#   'usd pledged': 310225.01,
#   'usd_pledged_real': 310225.01},
#  {'_id': ObjectId('5fc28bd6133d77838a7b6f5f'),
#   'ID': 1504572566,
#   'name': 'Novo - the smartest radiator valve',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2017-12-26',
#   'goal': 25000.0,
#   'launched': '2017-11-16 16:32:07',
#   'pledged': 208661.0,
#   'state': 'successful',
#   'backers': 1677.0,
#   'country': 'GB',
#   'usd pledged': 72720.53368146,
#   'usd_pledged_real': 282054.36677976185},
#  {'_id': ObjectId('5fc28bd6133d77838a7b71d4'),
#   'ID': 926266608,
#   'name': 'Modbook Pro X ï¿½ 15.4" Retina Quad-Core Mac OS X Tablet',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-07',
#   'goal': 150000.0,
#   'launched': '2014-07-30 18:57:35',
#   'pledged': 318244.34,
#   'state': 'successful',
#   'backers': 331.0,
#   'country': 'US',
#   'usd pledged': 318244.34,
#   'usd_pledged_real': 318244.34},
#  {'_id': ObjectId('5fc28bd6133d77838a7b71e8'),
#   'ID': 697445050,
#   'name': 'Remix IO - A 4K, Nougat-powered, All-in-One device',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-19',
#   'goal': 250000.0,
#   'launched': '2016-10-20 16:57:37',
#   'pledged': 598268.0,
#   'state': 'successful',
#   'backers': 4435.0,
#   'country': 'US',
#   'usd pledged': 233222.0,
#   'usd_pledged_real': 598268.0},
#  {'_id': ObjectId('5fc28bd6133d77838a7b7366'),
#   'ID': 849119531,
#   'name': 'Fief - France 1429',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-11',
#   'goal': 20000.0,
#   'launched': '2013-12-28 20:01:26',
#   'pledged': 408519.36,
#   'state': 'successful',
#   'backers': 4021.0,
#   'country': 'US',
#   'usd pledged': 408519.36,
#   'usd_pledged_real': 408519.36},
#  {'_id': ObjectId('5fc28bd6133d77838a7b73d5'),
#   'ID': 776266348,
#   'name': 'Posthuman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-24',
#   'goal': 27000.0,
#   'launched': '2015-03-25 22:52:43',
#   'pledged': 346071.0,
#   'state': 'successful',
#   'backers': 5323.0,
#   'country': 'US',
#   'usd pledged': 346071.0,
#   'usd_pledged_real': 346071.0},
#  ...]

# %%
collection.find({"pledged":{ "$gte" :  200000}}).count(True)
# Out:
# <ipython-input-33-89847bd35247>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({"pledged":{ "$gte" :  200000}}).count(True)
# 3612

# %% [markdown]
# ## Question 6

# %%
collection.find({"name" : {"$regex": ".*Sport.*"}}).count(True)
# Out:
# <ipython-input-34-2d7bebc3f7de>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({"name" : {"$regex": ".*Sport.*"}}).count(True)
# 2255
